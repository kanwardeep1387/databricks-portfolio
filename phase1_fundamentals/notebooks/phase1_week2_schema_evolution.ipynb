# %% [markdown]
# # **Set paths and read CSV**

# %%
from pyspark.sql.functions import current_timestamp

csv_path = "/Volumes/workspace/default/phase_1/sample_sales.csv" 
#delta_path = "/tmp/delta/sample_sales.delta"                # local Delta path for this lab     
#table_name = "sample_sales"                                 # will register this as a table

df = (spark.read
      .option("header", True)
      .option("inferSchema", True)
      .csv(csv_path))

display(df.limit(10))
print("Rows:", df.count())
df.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Enrich & write as Delta and Register as Delta table

# %%
df2 = df.withColumn("loaded_at", current_timestamp())
# write to Delta (overwrite for clean reruns)
(df2.write
 .format("delta")
 .mode("overwrite")
 .option("overwriteSchema", True)
 .save(delta_path))                     # error because writing to the public DBFS root (e.g., /tmp/delta/...) is disabled and not recommended in Databricks. You should write to a location in your workspace's cloud storage, such as an S3 bucket path

print("Delta written to:", delta_path)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperationException             Traceback (most recent call last)
# File <command-6991987240920551>, line 7
#       1 df2 = df.withColumn("loaded_at", current_timestamp())
#       2 # write to Delta (overwrite for clean reruns)
#       3 (df2.write
#       4  .format("delta")
#       5  .mode("overwrite")
#       6  .option("overwriteSchema", True)
# ----> 7  .save(delta_path))
#       9 print("Delta written to:", delta_path)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/readwriter.py:679, in DataFrameWriter.save(self, path, format, mode, partitionBy, **options)
#     677     self.format(format)
#     678 self._write.path = path
# --> 679 _, _, ei = self._spark.client.execute_command(
#     680     self._write.command(self._spark.client), self._write.observations
#     681 )
#     682 self._callback(ei)
#
# ...

# %% [markdown]
# # Now write a managed table in Unity Catalog

# %%
from pyspark.sql.functions import current_timestamp

table_fqn = "workspace.default.sample_sales" # <catalog>.<schema>.<table>

df2 = df.withColumn("loaded_at", current_timestamp())

# write as a managed Delta table (unity catalog)
(df2.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable(table_fqn))

print("Table written:", table_fqn)
# Out:
# Table written: workspace.default.sample_sales

# %% [markdown]
# ## Quick Checks

# %%
# %sql
select count(*) FROM workspace.default.sample_sales;
--DESCRIBE HISTORY workspace.default.sample_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>12</td></tr></tbody></table></div>

# %% [markdown]
# # Run a few starter queries

# %% [markdown]
# **Daily Revenue**

# %%
# %sql
select date, round(sum(revenue), 2) as daily_revenue
from sample_sales
group by date
order by date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>daily_revenue</th></tr></thead><tbody><tr><td>2025-09-01</td><td>129.97</td></tr><tr><td>2025-09-02</td><td>94.95</td></tr><tr><td>2025-09-03</td><td>52.48</td></tr><tr><td>2025-09-04</td><td>64.97</td></tr><tr><td>2025-09-05</td><td>108.97</td></tr><tr><td>2025-09-06</td><td>79.95</td></tr></tbody></table></div>

# %% [markdown]
# **Top 3 products by revenue**

# %%
# %sql
select product, round(sum(revenue), 2) as total_revenue
from sample_sales
group by product
order by total_revenue desc
limit 3;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>total_revenue</th></tr></thead><tbody><tr><td>Headphones</td><td>99.98</td></tr><tr><td>Jacket</td><td>79.99</td></tr><tr><td>Keyboard</td><td>59.99</td></tr></tbody></table></div>

# %% [markdown]
# **City-level revenue**

# %%
# %sql
select city, round(sum(revenue), 2) as total_revenue
from sample_sales
group by city
order by total_revenue desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>total_revenue</th></tr></thead><tbody><tr><td>Stockton</td><td>172.41</td></tr><tr><td>Tracy</td><td>124.99</td></tr><tr><td>Lodi</td><td>114.97</td></tr><tr><td>Manteca</td><td>78.93</td></tr><tr><td>Lathrop</td><td>39.99</td></tr></tbody></table></div>

# %% [markdown]
# **Peek at Delta History**
# This is useful later for time travel; seeing it now helps

# %%
# %sql
Describe history sample_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # Day 2 Objectives
#
# Understand schema evolution (adding new columns without breaking pipelines).
#
# Practice time travel – querying historical versions of your Delta table.
#
# Learn and apply OPTIMIZE + Z-ORDER for performance.
#
# Generate notebook & SQL deliverables for GitHub.

# %% [markdown]
# ## Step 1 — Schema Evolution (add new column)

# %%
# Add a new column (e.g., discount) to simulate schema evolution

from pyspark.sql.functions import rand
table_fqn = "workspace.default.sample_sales" # use same FQN as Day 1

# Read the existing Delta table
df_existing = spark.read.table(table_fqn)

# Add a new colmn 'discount'
df_new = df_existing.withColumn("discount", (rand()*0.15).cast("double"))

#write back with mergeSchema=True
(df_new.write
    .format("delta")
    .mode("overwrite")
    .option("mergeSchema", "true")
    .saveAsTable(table_fqn))
print("Schema evolved successfully ✅")
# Out:
# Schema evolved successfully ✅

# %% [markdown]
# Check the new column:

# %%
# %sql
DESCRIBE TABLE workspace.default.sample_sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## 🕓 Step 2 — Time Travel
# ##
# ## Each Delta write creates a version in the transaction log.

# %%
# %sql
Describe History sample_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Then query an older version — replace 0 or 1 with your actual version:

# %% [markdown]
# Version 0 of the table: without discount column, original schema

# %%
# %sql
select* from sample_sales version as of 0 limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Version 1 of the table: with discount column, evolved schema

# %%
# %sql
select* from sample_sales version as of 1 limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Query by timsestamp-based

# %%
# %sql
select* from workspace.default.sample_sales Timestamp as of "2025-10-21T10:00:00Z";
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## ⚡ Step 3 — Optimize & Z-Order
# ## Compact small files and improve query performance:

# %%
# %sql
OPTIMIZE sample_sales
ZORDER BY (date, product);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td></td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 3730), 0, List(0, 0), 0, null), null, 0, 0, 1, 1, false, 0, 0, 1762299649378, 1762299652563, 8, 0, null, List(0, 0), null, 12, 12, 0, 0, null)</td></tr></tbody></table></div>

# %% [markdown]
# 🔹 1. What is OPTIMIZE?
# Think of it as:
#
# 🧩 “Repacking the small puzzle pieces into bigger, well-organized blocks.”
#
# The OPTIMIZE command in Delta Lake:
#
# Compacts many small files into a few larger Parquet files (default target ≈ 1 GB each).
#
# Reduces metadata overhead → faster reads.
#
# Improves data skipping because fewer files must be checked.
#
# 🔹 2. What is ZORDER BY?
# Think of it as:
#
# 📚 “Re-arranging your library so related books are stored next to each other.”
#
# ZORDER (short for Z-ordering) is a multi-dimensional clustering technique.
# It physically re-organizes rows within files so that data with similar values for certain columns are stored close together.
